# %% [markdown]
# ## Using PIL for Image Processing

# %%
from PIL import Image

# %% [markdown]
# ## Original Image from Google Moon data

# %%
img = Image.open('/home/griggs/Galvanize_Course_Work/Capstone_Project/Moon_Images/Screenshot from 2017-03-05 21-35-56.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x900 at 0x7F98B46AA890>

# %% [markdown]
# ## Cropping off edges with unwanted text

# %%
img2 = img.crop((75, 250, 1150, 810))
img2
# Out:
# <PIL.Image.Image image mode=RGB size=1075x560 at 0x7F98BC56BA90>

# %% [markdown]
# ## Cutting 2nd horizontal strip into (8) 124x124 images
# ### Can make 32 images total.  Used 32 images in Batch Processing.

# %%
# Crop 1
img_crop_2_1 = img.crop((75, 250, 199, 374))
img_crop_2_1
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463CB10>

# %%
img_crop_2_2 = img.crop((200, 250, 324, 374))
img_crop_2_2
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463C250>

# %%
img_crop_2_3 = img.crop((325, 250, 449, 374))
img_crop_2_3
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463CB90>

# %%
img_crop_2_4 = img.crop((450, 250, 575, 374))
img_crop_2_4
# Out:
# <PIL.Image.Image image mode=RGB size=125x124 at 0x7F98B463CC10>

# %%
img_crop_2_5 = img.crop((575, 250, 699, 374))
img_crop_2_5
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463C550>

# %%
img_crop_2_6 = img.crop((700, 250, 824, 374))
img_crop_2_6
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463CB50>

# %%
img_crop_2_7 = img.crop((825, 250, 949, 374))
img_crop_2_7
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463CC90>

# %%
img_crop_2_8 = img.crop((950, 250, 1074, 374))
img_crop_2_8
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463CD10>

# %% [markdown]
# ## Original Image from Google Mars data

# %%
img = Image.open('/home/griggs/Galvanize_Course_Work/Capstone_Project/Mars_images/Screenshot from 2017-02-25 17-58-22.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x900 at 0x7F98B463CF50>

# %% [markdown]
# ## Cropping off edges with unwanted text

# %%
img2 = img.crop((75, 250, 1150, 810))
img2
# Out:
# <PIL.Image.Image image mode=RGB size=1075x560 at 0x7F98B45B9F50>

# %% [markdown]
# ## Cutting 2nd horizontal strip into (8) 124x124 images
# ### Can make 32 images total.  Used 32 images in Batch Processing.

# %%
# Crop 1
img_crop_2_1 = img.crop((75, 250, 199, 374))
img_crop_2_1
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B45B9E10>

# %%
img_crop_2_2 = img.crop((200, 250, 324, 374))
img_crop_2_2
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B45B94D0>

# %%
img_crop_2_3 = img.crop((325, 250, 449, 374))
img_crop_2_3
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B45B9210>

# %%
img_crop_2_4 = img.crop((450, 250, 575, 374))
img_crop_2_4
# Out:
# <PIL.Image.Image image mode=RGB size=125x124 at 0x7F98B45B9E90>

# %%
img_crop_2_5 = img.crop((575, 250, 699, 374))
img_crop_2_5
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98BC56B410>

# %%
img_crop_2_6 = img.crop((700, 250, 824, 374))
img_crop_2_6
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B463CFD0>

# %%
img_crop_2_7 = img.crop((825, 250, 949, 374))
img_crop_2_7
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98B45B91D0>

# %%
img_crop_2_8 = img.crop((950, 250, 1074, 374))
img_crop_2_8
# Out:
# <PIL.Image.Image image mode=RGB size=124x124 at 0x7F98BC56B490>

# %% [markdown]
# ## Trying out on Mars 'Face' image

# %%
img = Image.open('/home/griggs/Galvanize_Course_Work/Capstone_Project/images_Mars/face_on_mars.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=571x420 at 0x7F82CC6A0FD0>

# %%
# Crop 1
img_crop_2_1 = img.crop((250, 50, 374, 175))
img_crop_2_1
# Out:
# <PIL.Image.Image image mode=L size=124x125 at 0x7F98B45F7190>
